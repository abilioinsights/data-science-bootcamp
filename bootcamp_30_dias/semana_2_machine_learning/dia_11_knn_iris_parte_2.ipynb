# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, accuracy_score

# Carregar dataset
iris = load_iris()
X, y = iris.data, iris.target

# Dividir treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Normalizar os dados (KNN precisa!)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Treinar KNN com k=5 (padrão comum)
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train_scaled, y_train)

# Previsão
y_pred = knn.predict(X_test_scaled)

# Resultados
print("Acurácia KNN:", accuracy_score(y_test, y_pred))
print("\nRelatório de Classificação:\n", classification_report(y_test, y_pred, target_names=iris.target_names))
# Out:
# Acurácia KNN: 0.9111111111111111
#
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        15
#   versicolor       0.79      1.00      0.88        15
#    virginica       1.00      0.73      0.85        15
#
#     accuracy                           0.91        45
#    macro avg       0.93      0.91      0.91        45
# weighted avg       0.93      0.91      0.91        45

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, accuracy_score

# Carregar dataset
iris = load_iris()
X, y = iris.data, iris.target

# Dividir treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Normalizar os dados
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Testar diferentes valores de K
for k in [3, 5, 7]:
    print(f"\n--- K = {k} ---")
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train_scaled, y_train)
    y_pred = knn.predict(X_test_scaled)
    
    print("Acurácia:", accuracy_score(y_test, y_pred))
    print("Relatório de Classificação:\n", classification_report(y_test, y_pred, target_names=iris.target_names))
# Out:
# --- K = 3 ---
# Acurácia: 0.9111111111111111
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        15
#   versicolor       0.79      1.00      0.88        15
#    virginica       1.00      0.73      0.85        15
#
#     accuracy                           0.91        45
#    macro avg       0.93      0.91      0.91        45
# weighted avg       0.93      0.91      0.91        45
#
#
# --- K = 5 ---
# Acurácia: 0.9111111111111111
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        15
#   versicolor       0.79      1.00      0.88        15
#    virginica       1.00      0.73      0.85        15
#
#     accuracy                           0.91        45
#    macro avg       0.93      0.91      0.91        45
# weighted avg       0.93      0.91      0.91        45
#
#
# --- K = 7 ---
# Acurácia: 0.9333333333333333
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        15
#   versicolor       0.83      1.00      0.91        15
#    virginica       1.00      0.80      0.89        15
#
#     accuracy                           0.93        45
#    macro avg       0.94      0.93      0.93        45
# weighted avg       0.94      0.93      0.93        45

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report

# 1. Carregar dataset Iris
iris = load_iris()
X = iris.data
y = iris.target

# 2. Dividir em treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 3. Testar diferentes valores de K
for k in [1, 3, 5, 7, 9]:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)

    print(f"\n--- K = {k} ---")
    print("Acurácia:", accuracy_score(y_test, y_pred))
    print("Relatório de Classificação:")
    print(classification_report(y_test, y_pred))
# Out:
# --- K = 1 ---
# Acurácia: 1.0
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
#
#
# --- K = 3 ---
# Acurácia: 1.0
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
#
#
# --- K = 5 ---
# Acurácia: 1.0
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
#
#
# --- K = 7 ---
# Acurácia: 1.0
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
#
#
# --- K = 9 ---
# Acurácia: 1.0
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# 1. Gerar dados artificiais (duas "meias-luas")
X, y = make_moons(n_samples=300, noise=0.25, random_state=42)

# 2. Dividir em treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 3. Testar diferentes valores de K
k_values = [1, 3, 5, 15]
results = []

for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    results.append((k, acc))

    print(f"K={k} → Acurácia: {acc:.3f}")

# 4. Plotar a fronteira de decisão para cada K
from matplotlib.colors import ListedColormap
import numpy as np

fig, axes = plt.subplots(1, len(k_values), figsize=(16, 4))

for i, k in enumerate(k_values):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)

    # Geração da grade de pontos para visualização
    x_min, x_max = X[:, 0].min() - 0.5, X[:, 0].max() + 0.5
    y_min, y_max = X[:, 1].min() - 0.5, X[:, 1].max() + 0.5
    xx, yy = np.meshgrid(np.linspace(x_min, x_max, 200),
                         np.linspace(y_min, y_max, 200))

    Z = knn.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    axes[i].contourf(xx, yy, Z, alpha=0.3, cmap=ListedColormap(["#FFAAAA", "#AAAAFF"]))
    axes[i].scatter(X_test[:, 0], X_test[:, 1], c=y_test, edgecolor='k', cmap=ListedColormap(["#FF0000", "#0000FF"]))
    axes[i].set_title(f"K={k}")

plt.show()
# Out:
# K=1 → Acurácia: 0.956
# K=3 → Acurácia: 0.956
# K=5 → Acurácia: 0.944
# K=15 → Acurácia: 0.944

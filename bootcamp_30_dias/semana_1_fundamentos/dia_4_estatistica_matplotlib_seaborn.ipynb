# %% [markdown]
# # Dia 4 — 📊 Exercício: Estatística e Visualização com NumPy
#
# ## 🎯 Objetivo
# - Aplicar funções estatísticas e técnicas de visualização usando NumPy e Matplotlib para analisar dados numéricos.
#
# ## 📋 Parte 1 — Estatística
# ### Para a lista dados = [12, 15, 20, 22, 18, 17, 25, 30], calcule:
#
# - Média
#
# - Mediana
#
# - Desvio padrão
#
# - Variância
#
# - Correlação
#
# Em seguida, crie duas listas:

# %%
import numpy as np

# %%
# Lista de dados
dados = [12, 15, 20, 22, 18, 17, 25, 30]
dados_np = np.array(dados)

# %%
# Média
media = np.mean(dados_np)
print("Média:", media)

# Mediana
mediana = np.median(dados_np)
print("Mediana:", mediana)

# Desvio padrão
desvio_padrao = np.std(dados_np)
print("Desvio padrão:", desvio_padrao)

# Variância
variancia = np.var(dados_np)
print("Variância:", variancia)

# Correlação da lista consigo mesma (auto-correlação)
correlacao_auto = np.corrcoef(dados_np)
print("Correlação (auto):")
print(correlacao_auto)
# Out:
# Média: 19.875
# Mediana: 19.0
# Desvio padrão: 5.372092236736075
# Variância: 28.859375
# Correlação (auto):
# 1.0

# %% [markdown]
# # Correlação entre duas listas
# -  Plote um gráfico de linha para os valores de y em função de x.
#
# - Plote um histograma da lista dados.

# %%
# Listas x e y
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 5, 4, 5])

# Correlação entre x e y
correlacao_xy = np.corrcoef(x, y)
print("Correlação entre x e y:")
print(correlacao_xy)
# Out:
# Correlação entre x e y:
# [[1.         0.77459667]
#  [0.77459667 1.        ]]

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Estilo visual do Seaborn
sns.set(style="whitegrid")
# Dados
dados = [12, 15, 20, 22, 18, 17, 25, 30]
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 5, 4, 5])

# Estilo do Seaborn
sns.set(style="whitegrid")

# Gráfico de linha com Seaborn
plt.figure(figsize=(6, 4))
sns.lineplot(x=x, y=y, marker='o', color='blue')
plt.title("Gráfico de Linha: y em função de x")
plt.xlabel("x")
plt.ylabel("y")
plt.tight_layout()
plt.savefig("grafico_linha.png")  # Salva como imagem
plt.show()

# Histograma com Seaborn
plt.figure(figsize=(6, 4))
sns.histplot(dados, bins=5, kde=True, color='green')# kde = true add curva de densidade
plt.title("Histograma dos Dados")
plt.xlabel("Valor")
plt.ylabel("Frequência")
plt.tight_layout() # evita que o texto fique cortados
plt.savefig("histograma_dados.png")  # Salva como imagem
plt.show()
